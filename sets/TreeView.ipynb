# %%
using TreeView

# %%
@tree x^2 + y^2
# Out:
# LabelledTree({7, 6} directed simple Int64 graph, Any[:+, :^, :x, 2, :^, :y, 2])

# %%
using LazySets

# %%
A = rand(2, 2)
B = rand(2, 2)
S = rand(Singleton)
X = rand(BallInf)
# Out:
# BallInf{Float64}([1.7408410914221852, -0.5195787665250488], 0.5802989594842555)

# %%
@tree A * X
# Out:
# LabelledTree({3, 2} directed simple Int64 graph, Any[:*, :A, :X])

# %%
@tree LinearMap(A, X)
# Out:
# LabelledTree({3, 2} directed simple Int64 graph, Any[:LinearMap, :A, :X])

# %%
@tree MinkowskiSum(ConvexHull(S, A * S), (B * X))
# Out:
# LabelledTree({9, 8} directed simple Int64 graph, Any[:MinkowskiSum, :ConvexHull, :S, :*, :A, :S, :*, :B, :X])
