# %%
using Revise, LazySets, Plots

# %%
X = rand(HPolygon)
@time samples = sample(X, 1000, sampler=LazySets.HitAndRun)

plot(X)
plot!(Singleton(an_element(X)), c=:red)
plot!(Singleton.(samples))
# Out:
#   0.008756 seconds (100.98 k allocations: 9.099 MiB)
