# %% [markdown]
# ## Interval Hulls
#
# In this notebook we illustrate the symmetric interval hull operator as well as several plotting functionalities.

# %%
using LazySets, Plots

# %% [markdown]
# Let's create a ball in the 2-norm.

# %%
X = Ball2(ones(2), 0.5)
# Out:
# LazySets.Ball2{Float64}([1.0, 1.0], 0.5)

# %% [markdown]
# Observe that, by default, this coefficients of this set are 64-bit floating point numbers.

# %% [markdown]
# We can plot this set using the `plot` function. Recall that, by design, lazy sets plots overapproximate with box directions only. To have a sharp definition of the borders, use the accuracy as a second argument:

# %%
plot(X, 1e-3, aspectratio=1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6300)" points="
# 127.562,375.813 491.565,375.813 491.565,11.811 127.562,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="127" y="11" width="365" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   127.562,370.353 127.562,17.2711
#   "/>
# ...

# %% [markdown]
# Let's add to this plot some points of the set which are farthest in some given directions. Single points can be plotted using the `Singleton` type.
#
# To add a new plot to the previous one, use `plot!`. In the third line we plot the center of the ball with a cross marker.
#
# *Tip:* to see the list of available plot keyword arguments, use the `plotattr([attr])` function, where `attr` is the symbol `:Plot`, `:Series`, `:Axis` or `:Subplot`.

# %%
plot!(Singleton(σ([1., 0], X)))
plot!(Singleton(σ([1., 1], X)))
plot!(Singleton(X.center), markershape=:x)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6500)" points="
# 124.267,375.813 488.27,375.813 488.27,11.811 124.267,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="124" y="11" width="365" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   168.909,370.353 168.909,17.2711
#   "/>
# ...

# %% [markdown]
# The symmetric interval hull is defined in the `Approximations` module:

# %%
S = Approximations.symmetric_interval_hull(X)
# Out:
# LazySets.Hyperrectangle{Float64}([0.0, 0.0], [1.5, 1.5])

# %%
plot!(S, alpha=0.2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6700)" points="
# 127.728,375.813 491.73,375.813 491.73,11.811 127.728,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="127" y="11" width="365" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   138.03,370.353 138.03,17.2711
#   "/>
# ...

# %% [markdown]
# We can get the list of vertices using the `vertices_list` function:

# %%
vertices_list(S)
# Out:
# 4-element Array{Array{Float64,1},1}:
#  [1.5, 1.5]
#  [-1.5, 1.5]
#  [1.5, -1.5]
#  [-1.5, -1.5]

# %% [markdown]
# For instance, compute the support vector in the south-east direction:

# %%
σ([1., -1.], S)
# Out:
# 2-element Array{Float64,1}:
#   1.5
#  -1.5

# %% [markdown]
# It is also possible to pass a sparse vector as direction, and the result is a sparse vector:

# %%
σ(sparsevec([1., -1.]), S)
# Out:
# 2-element SparseVector{Float64,Int64} with 2 stored entries:
#   [1]  =  1.5
#   [2]  =  -1.5

# %% [markdown]
# Given two balls in the 2-norm, we build their convex hull and the overapproximation using the symmetric interval hull:

# %%
X = Ball2(ones(2), 0.5)
Y = Ball2([-3,-.5], 0.8)
Z = CH(X, Y)

plot(X, 1e-3, aspectratio=1)
plot!(Y, 1e-3)
plot!(Z, 1e-3, alpha=0.2)

plot!(Approximations.symmetric_interval_hull(Z), alpha=0.1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7100)" points="
# 39.1436,300.622 580.315,300.622 580.315,87.0021 39.1436,87.0021
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="87" width="542" height="215"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   96.109,297.418 96.109,90.2064
#   "/>
# ...

# %% [markdown]
# ---
